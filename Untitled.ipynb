# %%
import seaborn as sns
from matplotlib import pyplot as plt
# Out:
# c:\users\ajay tech\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot('total_bill','tip',data=tips,kind='hex',joint_kws={'gridsize':30,'edgecolors':'g'},marginal_kws={'bins':30,'color':'g'})
# Out:
# c:\users\ajay tech\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.hist("total_bill",data=tips)
plt.show()

# %%
plt.scatter("total_bill", "tip",data=tips)
plt.show()

# %%
sns.jointplot("total_bill", "tip",data=tips, color="k")
ax = plt.gca()
plt.show()

# %%
ax[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-b9c478fc82b3> in <module>
# ----> 1 ax[0]
#
# TypeError: 'AxesSubplot' object does not support indexing

# %%
g = sns.jointplot("total_bill", "tip",data=tips, color="k").plot_joint(sns.kdeplot)

# %%
g.plot_joint(sns.kdeplot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-ee8a54e47495> in <module>
# ----> 1 g.plot_joint(sns.kdeplot)
#
# c:\users\ajay tech\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\axisgrid.py in plot_joint(self, func, **kwargs)
#    1781
#    1782         """
# -> 1783         plt.sca(self.ax_joint)
#    1784         func(self.x, self.y, **kwargs)
#    1785
#
# c:\users\ajay tech\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in sca(ax)
#     911             m.canvas.figure.sca(ax)
#     912             return
# --> 913     raise ValueError("Axes instance argument was not found in a figure")
#     914
#     915
#
# ValueError: Axes instance argument was not found in a figure

# %%
g.ax_joint

# %%
type(g)
# Out:
# seaborn.axisgrid.JointGrid

# %%
k = sns.kdeplot(tips['total_bill'],tips['tip'])

# %%
k.figure

# %%
g?

# %%
type(g.ax_joint)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax1 = plt.subplot()

# %%
type(ax1)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
type(g.ax_marg_x)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
g.ax_joint?

# %%
type(g.ax_marg_y)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
g.ax_joint.zorder?

# %%
# Out:
# Object `zorder` not found.

# %%
g.fig.

# %%
g.x
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 20.29, 13.81, 11.02,
#        18.29, 17.59, 20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07,
#        26.86, 25.28, 14.73, 10.51, 17.92, 27.2 , 22.76, 17.29, 19.44,
#        16.66, 10.07, 32.68, 15.98, 34.83, 13.03, 18.28, 24.71, 21.16,
#        28.97, 22.49,  5.75, 16.32, 22.75, 40.17, 27.28, 12.03, 21.01,
#        12.46, 11.35, 15.38, 44.3 , 22.42, 20.92, 15.36, 20.49, 25.21,
#        18.24, 14.31, 14.  ,  7.25, 38.07, 23.95, 25.71, 17.31, 29.93,
# ...

# %%
g.y
# Out:
# array([ 1.01,  1.66,  3.5 ,  3.31,  3.61,  4.71,  2.  ,  3.12,  1.96,
#         3.23,  1.71,  5.  ,  1.57,  3.  ,  3.02,  3.92,  1.67,  3.71,
#         3.5 ,  3.35,  4.08,  2.75,  2.23,  7.58,  3.18,  2.34,  2.  ,
#         2.  ,  4.3 ,  3.  ,  1.45,  2.5 ,  3.  ,  2.45,  3.27,  3.6 ,
#         2.  ,  3.07,  2.31,  5.  ,  2.24,  2.54,  3.06,  1.32,  5.6 ,
#         3.  ,  5.  ,  6.  ,  2.05,  3.  ,  2.5 ,  2.6 ,  5.2 ,  1.56,
#         4.34,  3.51,  3.  ,  1.5 ,  1.76,  6.73,  3.21,  2.  ,  1.98,
#         3.76,  2.64,  3.15,  2.47,  1.  ,  2.01,  2.09,  1.97,  3.  ,
#         3.14,  5.  ,  2.2 ,  1.25,  3.08,  4.  ,  3.  ,  2.71,  3.  ,
#         3.4 ,  1.83,  5.  ,  2.03,  5.17,  2.  ,  4.  ,  5.85,  3.  ,
#         3.  ,  3.5 ,  1.  ,  4.3 ,  3.25,  4.73,  4.  ,  1.5 ,  3.  ,
#         1.5 ,  2.5 ,  3.  ,  2.5 ,  3.48,  4.08,  1.64,  4.06,  4.29,
#         3.76,  4.  ,  3.  ,  1.  ,  4.  ,  2.55,  4.  ,  3.5 ,  5.07,
# ...

# %%
g.ax_marg_x.

# %%
g.plot_joint()

# %%
g2 = sns.JointGrid('total_bill','tip',tips)
g2.plot_joint(sns.scatterplot)
g2.plot_marginals(sns.kdeplot)

# %%
g2.plot_joint(sns.scatterplot)
g2.plot_marginals(plt.hist,vertical='v')

# %%
g2.plot_marginals?

# %%
g3 = sns.JointGrid('total_bill','tip',tips)
g3.plot_joint(sns.scatterplot)
g3.plot_marginals(sns.distplot,kde=False)

# %%
g4 = sns.JointGrid('total_bill','tip',tips)
g4.ax_joint.scatter('total_bill','tip',data=tips)
#g4.ax_marg_y.kde('total_bill',data=tips)
#g4.ax_marg_y.kde('tip',data=tips)
sns.kdeplot(tips['total_bill'],ax=g4.ax_marg_x,vertical=False,shade='b')
sns.kdeplot(tips['tip'],ax=g4.ax_marg_y,vertical=True,shade='b')
g4.ax_joint.set_title('Joint grid')
g4.fig.suptitle('main')
plt.show()

# %%
g4

# %%
sns.boxplot(tips['tip'])

# %%
type(g4.ax_marg_y)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
g4.ax_marg_x.distplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-03c41d645e43> in <module>
# ----> 1 g4.ax_marg_x.distplot()
#
# AttributeError: 'AxesSubplot' object has no attribute 'distplot'

# %%
g4.fig.suptitle?

# %%
import matplotlib.pyplot as plt
import random

x = [random.randrange(100) for i in range(100)]
y = [random.randrange(100) for i in range(100)]
sns.distplot(x,kde=False,bins=20)
sns.distplot(y,color='r',kde=False,bins=20)

# %%
sns.distplot(x,kde=False)

# %%
sns.distplot(x)

# %%
sns.distplot(x,norm_hist=True,kde=False)

# %%
sns.distplot(x,norm_hist=False,kde=False)

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# Out:
# c:\users\ajay tech\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
tips = sns.load_dataset('tips')

# %%
from scipy.stats import norm
sns.distplot(a=tips['total_bill'],kde=False)
plt.show()

# %% [markdown]
# seaborn.jointplot(*, x=None, y=None, data=None, kind='scatter', color=None, height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, hue=None, palette=None, hue_order=None, hue_norm=None, **kwargs)

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],color='g',height=7,space=0,ratio=4,hue=tips['sex'],palette='Set1')

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind='kde')

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind='reg')

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind='hex')

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind='resid')

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind='hist')

# %%
X = [1,2,3,4,5,6,7]
Y = [8,9,10,11,12,13,14]
import matplotlib.pyplot as plt

plt.hist2d(X,Y,cmap='Pastel1') 
plt.show()

# %%
plt.hist2d?

# %%
sns.color_palette('Pastel1')
# Out:
# [(0.984313725490196, 0.7058823529411765, 0.6823529411764706),
#  (0.7019607843137254, 0.803921568627451, 0.8901960784313725),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (0.8705882352941177, 0.796078431372549, 0.8941176470588236),
#  (0.996078431372549, 0.8509803921568627, 0.6509803921568628),
#  (1.0, 1.0, 0.8),
#  (0.8980392156862745, 0.8470588235294118, 0.7411764705882353),
#  (0.9921568627450981, 0.8549019607843137, 0.9254901960784314),
#  (0.9490196078431372, 0.9490196078431372, 0.9490196078431372)]

# %%
X = [1,2,3,4,5,6,7]
Y = [40,60,80,100,110,120,140]
import matplotlib.pyplot as plt

plt.hist2d(X,Y,cmap='Pastel1') 
plt.show()

# %%
X = [1,2,3,4,5,6,7]
Y = [80,90,100,110,120,130,140]
import matplotlib.pyplot as plt

plt.hist2d(X,Y,cmap='Pastel1') 
plt.show()

# %%
X = [1,1,1]
Y = [5,10,15]
import matplotlib.pyplot as plt

plt.hist2d(X,Y,cmap='Set2') 
plt.show()

# %%
plt.scatter(X,Y,cmap='Set2',s=Y*5) 
plt.show()

# %%
X = [1,1,1,2,3,4]
Y = [5,5,15,5,10,15]
import matplotlib.pyplot as plt

plt.hist2d(X,Y,cmap='Pastel1') 
plt.show()

# %%
plt.scatter(X,Y,c=Y) 
plt.show()

# %%
x=[]
y= []
plt.hexbin(x,y) 
plt.show()

# %%
plt.hist2d(x,y) 
plt.show()

# %%
plt.hexbin(X,Y,cmap='Blues_r',gridsize=8) 
plt.show()

# %%
sns.color_palette('Set1')
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6)]

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],marginal_ticks=True)

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],marginal_ticks=False)

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],marginal_ticks=True,kind='kde')

# %%
a = sns.jointplot(x=tips['total_bill'],y=tips['tip'],marker='+',marginal_ticks=True,marginal_kws=dict(lw=3,fill=False))

# %%
a

# %%
type(a)
# Out:
# seaborn.axisgrid.JointGrid

# %%
g1 = sns.JointGrid(x=tips['total_bill'],y=tips['tip'])
g1.plot_joint(sns.scatterplot,style=tips['day'],size=10)
g1.plot_marginals(sns.histplot,kde=True)
g1.ax_joint.margins
plt.show()

# %%
g1

# %%
g1.plot_marginals(plt.hist,ax=g1.ax_marg_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-2e29910f5059> in <module>
# ----> 1 g1.plot_marginals(plt.hist,ax=g1.ax_marg_x)
#
# c:\users\ajay tech\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1725             kwargs.setdefault("legend", False)
#    1726
# -> 1727         plt.sca(self.ax_marg_x)
#    1728         if str(func.__module__).startswith("seaborn"):
#    1729             func(x=self.x, **kwargs)
#
# c:\users\ajay tech\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in sca(ax)
#     911             m.canvas.figure.sca(ax)
#     912             return
# --> 913     raise ValueError("Axes instance argument was not found in a figure")
#     914
#     915
#
# ValueError: Axes instance argument was not found in a figure

# %%
g2 = sns.JointGrid(x=tips['total_bill'],y=tips['tip'])
g2.plot(sns.scatterplot,sns.histplot,edgecolor='y',palette='Set2',hue=tips['sex'])
plt.show()

# %%
g3 = sns.JointGrid(x=tips['total_bill'],y=tips['tip'],hue=tips['day'],height=10,ratio=6)
g3.ax_marg_x.boxplot(x=tips['total_bill'],vert=False)
g3.ax_marg_y.boxplot(x=tips['tip'])
g3.ax_joint.hexbin(x=tips['total_bill'],y=tips['tip'],cmap='ocean_r',gridsize=30)
plt.show()

# %%
g3.ax_marg_x

# %%
g3.ax_marg_x.boxplot?

# %%
g3.ax_joint.hexbin?

# %%
g3.plot?

# %%
g4 = sns.JointGrid()

# %%
plt.hist2d?

# %%
g = sns.jointplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
g

# %%
type(g)
# Out:
# seaborn.axisgrid.JointGrid

# %%
g.fig

# %%
g.fig.gca
# Out:
# <bound method Figure.gca of <Figure size 432x432 with 3 Axes>>

# %%
g.fig?

## The top level container for all the plot elements. ##

# %%
g.fig.axes?

## List of axes in the Figure. You can access the axes in the Figure through this list.##

# %%
g.fig.axes

# %%
g.fig.axes[0]

# %%
type(g.fig.axes[0])
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
fig,ax = plt.subplots()

# %%
fig

# %%
ax

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-c089cbc1da03> in <module>
# ----> 1 fig.ax
#
# AttributeError: 'Figure' object has no attribute 'ax'

# %%
g1 = sns.JointGrid(x='total_bill',y='tip',data=tips)
#g1.plot_joint(plt.scatter)
#g1.plot_marginals(sns.kdeplot)


#g1 = sns.JointGrid(x='total_bill',y='tip',data=tips)
g1.plot_joint(plt.scatter,s=100,alpha=0.7)
g1.plot_marginals(sns.violinplot)
plt.show()

# %%
g1

# %%
g1.plot_marginals?

# %%
g2 =sns.JointGrid(x='total_bill',y='tip',data=tips,hue='day')
g2.plot(sns.scatterplot,sns.kdeplot,lw=2,color='y',alpha=0.2)



plt.show()

# %%
g3 = sns.JointGrid()
sns.kdeplot(x='total_bill',y='tip',data=tips,ax=g3.ax_joint)
sns.kdeplot(x='total_bill',data=tips,ax=g3.ax_marg_x,hue='smoker')
sns.histplot(y='tip',data=tips,fill=False,ax=g3.ax_marg_y)
plt.show()

# %%
sns.kdeplot(x='total_bill',y='tip',data=tips,ax=g3.ax_joint)
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

# %%
l = plt.plot(x,y)

# %%
type(l)
# Out:
# list

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cde25b5e10ad> in <module>
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_autogen_docstring',
#  '_backend_mod',
#  '_get_running_interactive_framework',
#  '_interactive_bk',
#  '_log',
# ...

# %%
g3.ax_marg_x.
# Out:
# Object `g3.ax_marg_x.hist` not found.
